# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('scraped_flight_data.csv')

# %%
df.head()
# Out:
#                                     Airline                Source  \
# 0  Delta • Operated by Virgin Atlantic, KLM  Toronto Pearson Intl
# 1  Delta • Operated by Virgin Atlantic, KLM  Toronto Pearson Intl
# 2  Delta • Operated by Virgin Atlantic, KLM  Toronto Pearson Intl
# 3       Delta • Operated by KLM, Air France  Toronto Pearson Intl
# 4       Delta • Operated by KLM, Air France  Toronto Pearson Intl
#
#       Destination Departure     Arrival Number of Stops  \
# 0  Bengaluru Intl  10:40 pm   2:45 am+3         2 stops
# 1  Bengaluru Intl  10:40 pm   2:45 am+3         2 stops
# 2  Bengaluru Intl  10:40 pm   2:45 am+3         2 stops
# 3  Bengaluru Intl  10:40 pm  11:55 pm+2         2 stops
# 4  Bengaluru Intl  10:40 pm  11:55 pm+2         2 stops
#
#                                     Stopover Details     Price       Class  \
# 0  , 19h 25m layover, <b>Amsterdam Schiphol</b>, ...  C$ 2,229  Main Cabin
# 1  , 20h 35m layover, <b>Amsterdam Schiphol</b>, ...  C$ 2,229  Main Cabin
# 2  , 22h 20m layover, <b>Amsterdam Schiphol</b>, ...  C$ 2,524  Main Cabin
# 3  , 4h 55m layover, <b>Amsterdam Schiphol</b>, ,...  C$ 3,690  Main Cabin
# 4  , 2h 10m layover, <b>Amsterdam Schiphol</b>, ,...  C$ 3,690  Main Cabin
#
#          Date
# 0  2024-06-22
# 1  2024-06-22
# 2  2024-06-22
# 3  2024-06-22
# 4  2024-06-22

# %%
# Define a function to clean and split the data
def clean_split_stopover(details):
    if isinstance(details, str):
        # Split the details by the delimiter ", , "
        parts = details.split(', , ')
        cleaned_parts = []
        for part in parts:
            # Extract the layover time and airport details
            time, airport = part.split(' layover, <b>')
            airport = airport.replace('</b>', '')
            cleaned_parts.append((time.strip(), airport.strip()))
        return cleaned_parts
    else:
        return []

# Apply the function to the 'Stopover Details' column
df['Cleaned Stopover Details'] = df['Stopover Details'].apply(clean_split_stopover)

# Convert the cleaned details into separate columns
stopover_df = df['Cleaned Stopover Details'].apply(pd.Series)

# Extract layover time and airport into separate columns
flat_df = pd.DataFrame()

for col in stopover_df.columns:
    temp_list = stopover_df[col].apply(lambda x: x if isinstance(x, tuple) else (np.nan, np.nan))
    temp_df = pd.DataFrame(temp_list.tolist(), columns=[f'Stopover_{col+1}_Time', f'Stopover_{col+1}_Airport'])
    flat_df = pd.concat([flat_df, temp_df], axis=1)

# Remove leading commas in Stopover_1_Time
flat_df['Stopover_1_Time'] = flat_df['Stopover_1_Time'].str.replace('^, ', '', regex=True)

# Function to convert time string to minutes
def time_to_minutes(time_str):
    if pd.isna(time_str):
        return 0
    hours, minutes = 0, 0
    if 'h' in time_str:
        hours = int(time_str.split('h')[0].strip())
        time_str = time_str.split('h')[1].strip()
    if 'm' in time_str:
        minutes = int(time_str.split('m')[0].strip())
    return hours * 60 + minutes

# Calculate total stopover time
flat_df['Total_Stopover_Time'] = flat_df[[col for col in flat_df.columns if 'Time' in col]].applymap(time_to_minutes).sum(axis=1)

# Convert total time back to hours and minutes
def minutes_to_time(minutes):
    hours = minutes // 60
    minutes = minutes % 60
    return f'{hours}h {minutes}m'

flat_df['Total_Stopover_Time'] = flat_df['Total_Stopover_Time'].apply(minutes_to_time)

# Show the final DataFrame
print(flat_df)
# Out:
# /var/folders/6c/n8sfjh_d78lfj_kyk83qgvy00000gn/T/ipykernel_17659/1600515772.py:46: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   flat_df['Total_Stopover_Time'] = flat_df[[col for col in flat_df.columns if 'Time' in col]].applymap(time_to_minutes).sum(axis=1)
#        Stopover_1_Time  Stopover_1_Airport Stopover_2_Time  \
# 0              19h 25m  Amsterdam Schiphol          4h 45m
# 1              20h 35m  Amsterdam Schiphol          3h 25m
# 2              22h 20m  Amsterdam Schiphol          1h 40m
# 3               4h 55m  Amsterdam Schiphol         16h 05m
# 4               2h 10m  Amsterdam Schiphol         18h 45m
# ...                ...                 ...             ...
# 207011          3h 35m    Addis Ababa Bole          5h 25m
# 207012          3h 35m    Addis Ababa Bole          4h 25m
# 207013          3h 35m    Addis Ababa Bole          9h 55m
# 207014          3h 35m    Addis Ababa Bole          5h 25m
# 207015          3h 35m    Addis Ababa Bole          9h 55m
#
#              Stopover_2_Airport Stopover_3_Time Stopover_3_Airport  \
# 0               London Heathrow             NaN                NaN
# 1               London Heathrow             NaN                NaN
# 2               London Heathrow             NaN                NaN
# 3       Paris Charles de Gaulle             NaN                NaN
# 4       Paris Charles de Gaulle             NaN                NaN
# ...                         ...             ...                ...
# 207011           Rome Fiumicino             NaN                NaN
# 207012           Rome Fiumicino             NaN                NaN
# 207013           Rome Fiumicino             NaN                NaN
# 207014           Rome Fiumicino             NaN                NaN
# 207015           Rome Fiumicino             NaN                NaN
#
#        Total_Stopover_Time
# 0                  24h 10m
# 1                   24h 0m
# 2                   24h 0m
# 3                   21h 0m
# 4                  20h 55m
# ...                    ...
# 207011               9h 0m
# 207012               8h 0m
# 207013             13h 30m
# 207014               9h 0m
# 207015             13h 30m
#
# [207016 rows x 7 columns]

# %%
flat_df.head()
# Out:
#   Stopover_1_Time  Stopover_1_Airport Stopover_2_Time  \
# 0         19h 25m  Amsterdam Schiphol          4h 45m
# 1         20h 35m  Amsterdam Schiphol          3h 25m
# 2         22h 20m  Amsterdam Schiphol          1h 40m
# 3          4h 55m  Amsterdam Schiphol         16h 05m
# 4          2h 10m  Amsterdam Schiphol         18h 45m
#
#         Stopover_2_Airport Stopover_3_Time Stopover_3_Airport  \
# 0          London Heathrow             NaN                NaN
# 1          London Heathrow             NaN                NaN
# 2          London Heathrow             NaN                NaN
# 3  Paris Charles de Gaulle             NaN                NaN
# 4  Paris Charles de Gaulle             NaN                NaN
#
#   Total_Stopover_Time
# 0             24h 10m
# 1              24h 0m
# 2              24h 0m
# 3              21h 0m
# 4             20h 55m

# %%
# Combine flat_df with the original df
df = pd.concat([df, flat_df], axis=1)

# %%
df.head()
# Out:
#                                     Airline                Source  \
# 0  Delta • Operated by Virgin Atlantic, KLM  Toronto Pearson Intl
# 1  Delta • Operated by Virgin Atlantic, KLM  Toronto Pearson Intl
# 2  Delta • Operated by Virgin Atlantic, KLM  Toronto Pearson Intl
# 3       Delta • Operated by KLM, Air France  Toronto Pearson Intl
# 4       Delta • Operated by KLM, Air France  Toronto Pearson Intl
#
#       Destination Departure     Arrival Number of Stops  \
# 0  Bengaluru Intl  10:40 pm   2:45 am+3         2 stops
# 1  Bengaluru Intl  10:40 pm   2:45 am+3         2 stops
# 2  Bengaluru Intl  10:40 pm   2:45 am+3         2 stops
# 3  Bengaluru Intl  10:40 pm  11:55 pm+2         2 stops
# 4  Bengaluru Intl  10:40 pm  11:55 pm+2         2 stops
#
#                                     Stopover Details     Price       Class  \
# 0  , 19h 25m layover, <b>Amsterdam Schiphol</b>, ...  C$ 2,229  Main Cabin
# 1  , 20h 35m layover, <b>Amsterdam Schiphol</b>, ...  C$ 2,229  Main Cabin
# 2  , 22h 20m layover, <b>Amsterdam Schiphol</b>, ...  C$ 2,524  Main Cabin
# 3  , 4h 55m layover, <b>Amsterdam Schiphol</b>, ,...  C$ 3,690  Main Cabin
# 4  , 2h 10m layover, <b>Amsterdam Schiphol</b>, ,...  C$ 3,690  Main Cabin
#
#          Date                           Cleaned Stopover Details  \
# 0  2024-06-22  [(, 19h 25m, Amsterdam Schiphol), (4h 45m, Lon...
# 1  2024-06-22  [(, 20h 35m, Amsterdam Schiphol), (3h 25m, Lon...
# 2  2024-06-22  [(, 22h 20m, Amsterdam Schiphol), (1h 40m, Lon...
# 3  2024-06-22  [(, 4h 55m, Amsterdam Schiphol), (16h 05m, Par...
# 4  2024-06-22  [(, 2h 10m, Amsterdam Schiphol), (18h 45m, Par...
#
#   Stopover_1_Time  Stopover_1_Airport Stopover_2_Time  \
# 0         19h 25m  Amsterdam Schiphol          4h 45m
# 1         20h 35m  Amsterdam Schiphol          3h 25m
# 2         22h 20m  Amsterdam Schiphol          1h 40m
# 3          4h 55m  Amsterdam Schiphol         16h 05m
# 4          2h 10m  Amsterdam Schiphol         18h 45m
#
#         Stopover_2_Airport Stopover_3_Time Stopover_3_Airport  \
# 0          London Heathrow             NaN                NaN
# 1          London Heathrow             NaN                NaN
# 2          London Heathrow             NaN                NaN
# 3  Paris Charles de Gaulle             NaN                NaN
# 4  Paris Charles de Gaulle             NaN                NaN
#
#   Total_Stopover_Time
# 0             24h 10m
# 1              24h 0m
# 2              24h 0m
# 3              21h 0m
# 4             20h 55m

# %%
df = df.drop(columns=['Cleaned Stopover Details','Stopover Details'])

# %%
df.head()
# Out:
#                                     Airline                Source  \
# 0  Delta • Operated by Virgin Atlantic, KLM  Toronto Pearson Intl
# 1  Delta • Operated by Virgin Atlantic, KLM  Toronto Pearson Intl
# 2  Delta • Operated by Virgin Atlantic, KLM  Toronto Pearson Intl
# 3       Delta • Operated by KLM, Air France  Toronto Pearson Intl
# 4       Delta • Operated by KLM, Air France  Toronto Pearson Intl
#
#       Destination Departure     Arrival Number of Stops     Price       Class  \
# 0  Bengaluru Intl  10:40 pm   2:45 am+3         2 stops  C$ 2,229  Main Cabin
# 1  Bengaluru Intl  10:40 pm   2:45 am+3         2 stops  C$ 2,229  Main Cabin
# 2  Bengaluru Intl  10:40 pm   2:45 am+3         2 stops  C$ 2,524  Main Cabin
# 3  Bengaluru Intl  10:40 pm  11:55 pm+2         2 stops  C$ 3,690  Main Cabin
# 4  Bengaluru Intl  10:40 pm  11:55 pm+2         2 stops  C$ 3,690  Main Cabin
#
#          Date Stopover_1_Time  Stopover_1_Airport Stopover_2_Time  \
# 0  2024-06-22         19h 25m  Amsterdam Schiphol          4h 45m
# 1  2024-06-22         20h 35m  Amsterdam Schiphol          3h 25m
# 2  2024-06-22         22h 20m  Amsterdam Schiphol          1h 40m
# 3  2024-06-22          4h 55m  Amsterdam Schiphol         16h 05m
# 4  2024-06-22          2h 10m  Amsterdam Schiphol         18h 45m
#
#         Stopover_2_Airport Stopover_3_Time Stopover_3_Airport  \
# 0          London Heathrow             NaN                NaN
# 1          London Heathrow             NaN                NaN
# 2          London Heathrow             NaN                NaN
# 3  Paris Charles de Gaulle             NaN                NaN
# 4  Paris Charles de Gaulle             NaN                NaN
#
#   Total_Stopover_Time
# 0             24h 10m
# 1              24h 0m
# 2              24h 0m
# 3              21h 0m
# 4             20h 55m

# %%
# Split the 'Airline' column at '• Operated by', handle missing parts by filling with None
split_df = df['Airline'].str.split('• Operated by', n=1, expand=True)

# Assign split data to new columns and fill missing values
df['Airline'] = split_df[0].str.strip()
df['Operated'] = split_df[1].str.strip().fillna('None')

# Display the resulting DataFrame
print(df)
# Out:
#                           Airline                    Source  \
# 0                           Delta      Toronto Pearson Intl
# 1                           Delta      Toronto Pearson Intl
# 2                           Delta      Toronto Pearson Intl
# 3                           Delta      Toronto Pearson Intl
# 4                           Delta      Toronto Pearson Intl
# ...                           ...                       ...
# 207011          Multiple Airlines  Kano Aminu Kano Intl Apt
# 207012  Ethiopian Air, Air Canada  Kano Aminu Kano Intl Apt
# 207013          Multiple Airlines  Kano Aminu Kano Intl Apt
# 207014          Multiple Airlines  Kano Aminu Kano Intl Apt
# 207015          Multiple Airlines  Kano Aminu Kano Intl Apt
#
#                  Destination Departure     Arrival Number of Stops      Price  \
# 0             Bengaluru Intl  10:40 pm   2:45 am+3         2 stops   C$ 2,229
# 1             Bengaluru Intl  10:40 pm   2:45 am+3         2 stops   C$ 2,229
# 2             Bengaluru Intl  10:40 pm   2:45 am+3         2 stops   C$ 2,524
# 3             Bengaluru Intl  10:40 pm  11:55 pm+2         2 stops   C$ 3,690
# 4             Bengaluru Intl  10:40 pm  11:55 pm+2         2 stops   C$ 3,690
# ...                      ...       ...         ...             ...        ...
# 207011  Toronto Pearson Intl   1:35 pm   1:35 pm+1         2 stops  C$ 19,538
# 207012  Toronto Pearson Intl   1:35 pm   1:35 pm+1         2 stops  C$ 19,582
# 207013  Toronto Pearson Intl   1:35 pm   6:05 pm+1         2 stops  C$ 19,538
# 207014  Toronto Pearson Intl   1:35 pm   1:35 pm+1         2 stops  C$ 20,074
# 207015  Toronto Pearson Intl   1:35 pm   6:05 pm+1         2 stops  C$ 20,074
#
#                     Class        Date Stopover_1_Time  Stopover_1_Airport  \
# 0              Main Cabin  2024-06-22         19h 25m  Amsterdam Schiphol
# 1              Main Cabin  2024-06-22         20h 35m  Amsterdam Schiphol
# 2              Main Cabin  2024-06-22         22h 20m  Amsterdam Schiphol
# 3              Main Cabin  2024-06-22          4h 55m  Amsterdam Schiphol
# 4              Main Cabin  2024-06-22          2h 10m  Amsterdam Schiphol
# ...                   ...         ...             ...                 ...
# 207011     Business Saver  2024-08-13          3h 35m    Addis Ababa Bole
# 207012  Business Flexible  2024-08-13          3h 35m    Addis Ababa Bole
# 207013     Business Saver  2024-08-13          3h 35m    Addis Ababa Bole
# 207014    Business Lowest  2024-08-13          3h 35m    Addis Ababa Bole
# 207015    Business Lowest  2024-08-13          3h 35m    Addis Ababa Bole
#
#        Stopover_2_Time       Stopover_2_Airport Stopover_3_Time  \
# 0               4h 45m          London Heathrow             NaN
# 1               3h 25m          London Heathrow             NaN
# 2               1h 40m          London Heathrow             NaN
# 3              16h 05m  Paris Charles de Gaulle             NaN
# 4              18h 45m  Paris Charles de Gaulle             NaN
# ...                ...                      ...             ...
# 207011          5h 25m           Rome Fiumicino             NaN
# 207012          4h 25m           Rome Fiumicino             NaN
# 207013          9h 55m           Rome Fiumicino             NaN
# 207014          5h 25m           Rome Fiumicino             NaN
# 207015          9h 55m           Rome Fiumicino             NaN
#
#        Stopover_3_Airport Total_Stopover_Time                   Operated
# 0                     NaN             24h 10m       Virgin Atlantic, KLM
# 1                     NaN              24h 0m       Virgin Atlantic, KLM
# 2                     NaN              24h 0m       Virgin Atlantic, KLM
# 3                     NaN              21h 0m            KLM, Air France
# 4                     NaN             20h 55m            KLM, Air France
# ...                   ...                 ...                        ...
# 207011                NaN               9h 0m  Ethiopian Air, Air Canada
# 207012                NaN               8h 0m                       None
# 207013                NaN             13h 30m  Ethiopian Air, Air Canada
# 207014                NaN               9h 0m              Ethiopian Air
# 207015                NaN             13h 30m              Ethiopian Air
#
# [207016 rows x 17 columns]

# %%
# Remove the 'C$' prefix and commas, and convert to numeric
df['price in CAD'] = df['Price'].str.replace('C$', '').str.replace(',', '').astype(int)

# Drop the old 'Price' column
df = df.drop(columns=['Price'])

# %%
df.head()
# Out:
#   Airline                Source     Destination Departure     Arrival  \
# 0   Delta  Toronto Pearson Intl  Bengaluru Intl  10:40 pm   2:45 am+3
# 1   Delta  Toronto Pearson Intl  Bengaluru Intl  10:40 pm   2:45 am+3
# 2   Delta  Toronto Pearson Intl  Bengaluru Intl  10:40 pm   2:45 am+3
# 3   Delta  Toronto Pearson Intl  Bengaluru Intl  10:40 pm  11:55 pm+2
# 4   Delta  Toronto Pearson Intl  Bengaluru Intl  10:40 pm  11:55 pm+2
#
#   Number of Stops       Class        Date Stopover_1_Time  Stopover_1_Airport  \
# 0         2 stops  Main Cabin  2024-06-22         19h 25m  Amsterdam Schiphol
# 1         2 stops  Main Cabin  2024-06-22         20h 35m  Amsterdam Schiphol
# 2         2 stops  Main Cabin  2024-06-22         22h 20m  Amsterdam Schiphol
# 3         2 stops  Main Cabin  2024-06-22          4h 55m  Amsterdam Schiphol
# 4         2 stops  Main Cabin  2024-06-22          2h 10m  Amsterdam Schiphol
#
#   Stopover_2_Time       Stopover_2_Airport Stopover_3_Time Stopover_3_Airport  \
# 0          4h 45m          London Heathrow             NaN                NaN
# 1          3h 25m          London Heathrow             NaN                NaN
# 2          1h 40m          London Heathrow             NaN                NaN
# 3         16h 05m  Paris Charles de Gaulle             NaN                NaN
# 4         18h 45m  Paris Charles de Gaulle             NaN                NaN
#
#   Total_Stopover_Time              Operated  price in CAD
# 0             24h 10m  Virgin Atlantic, KLM          2229
# 1              24h 0m  Virgin Atlantic, KLM          2229
# 2              24h 0m  Virgin Atlantic, KLM          2524
# 3              21h 0m       KLM, Air France          3690
# 4             20h 55m       KLM, Air France          3690

# %%
df.shape
# Out:
# (207016, 17)

# %%
# df.to_csv('Rehan.csv', index=False)

# %%
from datetime import datetime, timedelta

# Function to calculate days_left
def calculate_days_left(flight_date):
    start_date = datetime(2024, 6, 22)
    current_date = datetime.strptime(flight_date, '%Y-%m-%d')
    return (current_date - start_date).days + 1

# Apply the function to create the new column
df['days_left'] = df['Date'].apply(calculate_days_left)

# Display the updated dataframe
df.head()
# Out:
#   Airline                Source     Destination Departure     Arrival  \
# 0   Delta  Toronto Pearson Intl  Bengaluru Intl  10:40 pm   2:45 am+3
# 1   Delta  Toronto Pearson Intl  Bengaluru Intl  10:40 pm   2:45 am+3
# 2   Delta  Toronto Pearson Intl  Bengaluru Intl  10:40 pm   2:45 am+3
# 3   Delta  Toronto Pearson Intl  Bengaluru Intl  10:40 pm  11:55 pm+2
# 4   Delta  Toronto Pearson Intl  Bengaluru Intl  10:40 pm  11:55 pm+2
#
#   Number of Stops       Class        Date Stopover_1_Time  Stopover_1_Airport  \
# 0         2 stops  Main Cabin  2024-06-22         19h 25m  Amsterdam Schiphol
# 1         2 stops  Main Cabin  2024-06-22         20h 35m  Amsterdam Schiphol
# 2         2 stops  Main Cabin  2024-06-22         22h 20m  Amsterdam Schiphol
# 3         2 stops  Main Cabin  2024-06-22          4h 55m  Amsterdam Schiphol
# 4         2 stops  Main Cabin  2024-06-22          2h 10m  Amsterdam Schiphol
#
#   Stopover_2_Time       Stopover_2_Airport Stopover_3_Time Stopover_3_Airport  \
# 0          4h 45m          London Heathrow             NaN                NaN
# 1          3h 25m          London Heathrow             NaN                NaN
# 2          1h 40m          London Heathrow             NaN                NaN
# 3         16h 05m  Paris Charles de Gaulle             NaN                NaN
# 4         18h 45m  Paris Charles de Gaulle             NaN                NaN
#
#   Total_Stopover_Time              Operated  price in CAD  days_left
# 0             24h 10m  Virgin Atlantic, KLM          2229          1
# 1              24h 0m  Virgin Atlantic, KLM          2229          1
# 2              24h 0m  Virgin Atlantic, KLM          2524          1
# 3              21h 0m       KLM, Air France          3690          1
# 4             20h 55m       KLM, Air France          3690          1

# %%
df.to_csv('Final3.csv', index=False)
